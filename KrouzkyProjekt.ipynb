# %%
import pandas as pd

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('krouzkytaboryPowerBI POSLEDNI VSECHNY.xlsx', engine='openpyxl')
print(df.head())
# Out:
#    ID                                Name       Name_Organization   Category  \
# 0   1  Balet pro děti Baletní škola Baláž     Baletní škola Baláž  sportovní
# 1   2                   4 - 5 let nováčci  Baletní škola Filiánek  sportovní
# 2   3                 8 + let soutěžní M1  Baletní škola Filiánek  sportovní
# 3   4                  9 + let  pokročilí  Baletní škola Filiánek  sportovní
# 4   5               13 + let  soutěžní M3  Baletní škola Filiánek  sportovní
#
#    City-district  City  District                                Adress  \
# 0  Brno-Židenice  Brno  Židenice  Zábrdovická 10, 615 00 Brno-Židenice
# 1     Brno-Střed  Brno     Střed        Antonínská 564/18, 602 00 Brno
# 2     Brno-Střed  Brno     Střed        Antonínská 564/18, 602 00 Brno
# 3     Brno-Střed  Brno     Střed        Antonínská 564/18, 602 00 Brno
# 4     Brno-Střed  Brno     Střed        Antonínská 564/18, 602 00 Brno
#
#   Age_grop Capacity   Price       Day         Time  \
# ...

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False) 
print(df)
# Out:
#         ID                                Name                   Name_Organization   Category  City-district  City  District                                       Adress Age_grop Capacity   Price       Day         Time                             Web
# 0        1  Balet pro děti Baletní škola Baláž                 Baletní škola Baláž  sportovní  Brno-Židenice  Brno  Židenice         Zábrdovická 10, 615 00 Brno-Židenice   3 – 15    volno  3790.0       NaN          NaN  https://www.krouzkyatabory.cz/
# 1        2                   4 - 5 let nováčci              Baletní škola Filiánek  sportovní     Brno-Střed  Brno     Střed               Antonínská 564/18, 602 00 Brno    4 – 5    volno  3300.0  Pondělí   14:15-15:00  https://www.balet-filianek.cz/
# ...

# %%
df['Category'] = df['Category'].replace('Jazykový kurz', 'jazykové')
df['Category'] = df['Category'].replace('Věda, technika a stavebnice', 'vědecké')
df['Category'] = df['Category'].replace('Pohybové a taneční, Rodiče a děti', 'sportovní')
df['Category'] = df['Category'].replace('Kluby s výlety', 'ostatní')
df['Category'] = df['Category'].replace('Hry, Programování a robotika, Věda, technika a stavebnice', 'ostatní')
df['Category'] = df['Category'].replace('Přírodovědné', 'přírodovědecké')
df['Category'] = df['Category'].replace('Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Pohybové a taneční', 'sportovní')
df['Category'] = df['Category'].replace('Dramatické', 'dramatické')
df['Category'] = df['Category'].replace('Hry, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Hry, Programování a robotika', 'technické')
df['Category'] = df['Category'].replace('Hry, Pohybové a taneční, Rodiče a děti', 'sportovní')
df['Category'] = df['Category'].replace('Hry, Pohybové a taneční, Pro předškolní děti, Rodiče a děti', 'sportovní')
df['Category'] = df['Category'].replace('Pohybové a taneční, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Rukodělné, Výtvarné a keramické', 'ostatní')
df['Category'] = df['Category'].replace('Pro dospělé, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Vaření a pečení', 'ostatní')
df['Category'] = df['Category'].replace('Rukodělné, Výtvarné a keramické', 'sportovní')
df['Category'] = df['Category'].replace('Pro předškolní děti, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Rodiče a děti', 'ostatní')
df['Category'] = df['Category'].replace('Pohybové a taneční, Pro předškolní děti, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Rodiče a děti, Výtvarné a keramické', 'ostatní')
df['Category'] = df['Category'].replace('Programování a robotika', 'technické')
df['Category'] = df['Category'].replace('Pro předškolní děti, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Přírodovědné, Výtvarné a keramické', 'přírodovědecké')
df['Category'] = df['Category'].replace('Kluby, Pro dospělé', 'ostatní')
df['Category'] = df['Category'].replace('Hudební, Pro předškolní děti', 'hudební')
df['Category'] = df['Category'].replace('Jazykové, Pro předškolní děti', 'jazykové')
df['Category'] = df['Category'].replace('Hudební, Pro předškolní děti, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Rukodělné, Vaření a pečení, Výtvarné a keramické', 'ostatní')
df['Category'] = df['Category'].replace('Kluby s výlety, Přírodovědné', 'přírodovědecké')
df['Category'] = df['Category'].replace('Hudebně – dramatické-divadlo', 'dramatické')
df['Category'] = df['Category'].replace('PC a technika-programování', 'technické')
df['Category'] = df['Category'].replace('Člověk a jeho svět-deskové hry', 'ostatní')
df['Category'] = df['Category'].replace('Člověk a jeho svět-záchranáři', 'ostatní')
df['Category'] = df['Category'].replace('Hry, Jazykové, Pro předškolní děti', 'jazykové')
df['Category'] = df['Category'].replace('Pro předškolní děti, Rukodělné, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Rodiče a děti, Věda, technika a stavebnice', 'vědecké')
df['Category'] = df['Category'].replace('Rodiče a děti, Rukodělné, Výtvarné a keramické', 'ostatní')
df['Category'] = df['Category'].replace('Hudební, Pohybové a taneční, Pro předškolní děti', 'hudební')
df['Category'] = df['Category'].replace('Dramatické, Ostatní, Pohybové a taneční', 'dramatické')
df['Category'] = df['Category'].replace('Ostatní, Vaření a pečení', 'ostatní')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-kondiční trénink', 'sportovní')
df['Category'] = df['Category'].replace('Hudebně – dramatické-výrazový tanec', 'sportovní')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-výtvarka', 'umělecké')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-bojová umění', 'sportovní')
df['Category'] = df['Category'].replace('Člověk a jeho svět-kluby pro děti', 'ostatní')
df['Category'] = df['Category'].replace('Člověk a jeho svět-jazyky', 'jazykové')
df['Category'] = df['Category'].replace('Všestranný rozvoj pro nejmenší-předškoláci', 'pro nejmenší')
df['Category'] = df['Category'].replace('Rodiče a děti, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Ostatní, Rodiče a děti, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Pro dospělé, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Hry, Ostatní, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Pro předškolní děti', 'sportovní')
df['Category'] = df['Category'].replace('Kluby', 'technické')
df['Category'] = df['Category'].replace('Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Hudební', 'hudební')
df['Category'] = df['Category'].replace('Jazykové', 'jazykové')
df['Category'] = df['Category'].replace('Všestranný rozvoj pro nejmenší-1-3 roky', 'pro nejmenší')
df['Category'] = df['Category'].replace('Hudebně – dramatické-hudba', 'hudební')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-keramika', 'umělecké')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-vaření', 'ostatní')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-kondiční tréninky', 'sportovní')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-míčové hry', 'sportovní')
df['Category'] = df['Category'].replace('Všestranný rozvoj pro nejmenší-kojenci', 'pro nejmenší')
df['Category'] = df['Category'].replace('Média-foto a video', 'technické')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-akrobacie a cirkus', 'sportovní')
df['Category'] = df['Category'].replace('Přírodověda-přírodní vědy v praxi (pokusy)', 'přírodovědecké')
df['Category'] = df['Category'].replace('Přírodověda-zvířata', 'přírodovědecké')
df['Category'] = df['Category'].replace('Člověk a jeho svět-výlety a exkurze', 'ostatní')
df['Category'] = df['Category'].replace('Přírodověda-rostliny', 'přírodovědecké')
df['Category'] = df['Category'].replace('Hudebně – dramatické-hudba', 'hudební')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-dívčí kluby', 'umělecké')
df['Category'] = df['Category'].replace('Speciální péče-příprava na SŠ', 'vědecké')
df['Category'] = df['Category'].replace('PC a technika-robotika', 'technické')
df['Category'] = df['Category'].replace('Hudebně – dramatické-hudba', 'hudební')
df['Category'] = df['Category'].replace('Hudebně – dramatické-zpěv', 'hudební')
df['Category'] = df['Category'].replace('Pro předškolní děti, Sportovní', 'sportovní')
df['Category'] = df['Category'].replace('Přírodovědné, Sportovní', 'přírodovědecké')
df['Category'] = df['Category'].replace('Hudební, Pohybové a taneční', 'hudební')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-gymnastika a mažoretky', 'sportovní')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-ostatní sporty', 'sportovní')
df['Category'] = df['Category'].replace('PC a technika-počítačové hry', 'technické')
df['Category'] = df['Category'].replace('PC a technika-elektro', 'technické')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-jóga a zdraví', 'sportovní')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-práce s materiály (dřevo, kov, apod.)', 'umělecké')
df['Category'] = df['Category'].replace('Sport a pohybové aktivity-všestranný sportovní rozvoj', 'sportovní')
df['Category'] = df['Category'].replace('SPC a technika-3D modelářství (tiskárny, letečtí, papíroví)', 'technické')
df['Category'] = df['Category'].replace('Jazykové, Ostatní', 'ostatní')
df['Category'] = df['Category'].replace('Hry, Kluby', 'ostatní')
df['Category'] = df['Category'].replace('Kluby, Rukodělné, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Kluby, Programování a robotika, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('PC a technika-3D modelářství (tiskárny, letečtí, papíroví)', 'technické')
df['Category'] = df['Category'].replace('Ostatní, Programování a robotika, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Pro předškolní děti, Rodiče a děti, Výtvarné a keramické', 'technické')
df['Category'] = df['Category'].replace('Hry, Programování a robotika, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Dramatické, Kluby, Pohybové a taneční, Rukodělné, Vaření a pečení, Věda, technika a stavebnice, Výtvarné a keramické', 'ostatní')
df['Category'] = df['Category'].replace('Hry, Jazykové', 'jazykové')
df['Category'] = df['Category'].replace('Hry, Výtvarné a keramické', 'umělecké')
df['Category'] = df['Category'].replace('Člověk a jeho svět-kluby pro dospělé a seniory', 'ostatní')
df['Category'] = df['Category'].replace('Člověk a jeho svět-dopravní kluby', 'ostatní')
df['Category'] = df['Category'].replace('Rukodělné a výtvarné-šití', 'ostatní')
df['Category'] = df['Category'].replace('Programování a robotika, Věda, technika a stavebnice', 'technické')
df['Category'] = df['Category'].replace('Ostatní, Věda, technika a stavebnice, Výtvarné a keramické', 'technické')
df['Category'] = df['Category'].replace('Hry, Kluby, Programování a robotika, Věda, technika a stavebnice', 'technické')

# %%
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)  


print(df)
# Out:
#         ID                                               Name                                  Name_Organization                                           Category                City-district     City                District                                             Adress           Age_grop  Capacity    Price       Day          Time                                               Web
# 0        1                 Balet pro děti Baletní škola Baláž                                Baletní škola Baláž                                          sportovní                Brno-Židenice     Brno                Židenice               Zábrdovická 10, 615 00 Brno-Židenice             3 – 15     volno   3790.0       NaN           NaN                    https://www.krouzkyatabory.cz/
# ...

# %%
df.to_excel('krouzkytaboryPowerBI_updated.xlsx', index=False, engine='openpyxl')
